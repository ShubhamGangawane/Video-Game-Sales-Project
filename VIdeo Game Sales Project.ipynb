# %% [markdown]
# ### Import Essestinal Libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
game = pd.read_csv('C:\\Users\Anjali\\Documents\\Jupter\\Project\\vgsales.csv')
game.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# ### info() method to find out the entries and Dtype

# %%
game.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Checking the Null values

# %%
game.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %% [markdown]
# ### Droping the Null Values

# %%
game.dropna(inplace=True)

# %%
game.isna().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %% [markdown]
# ### changing Float Year column into Int

# %%
game['Year']= game.Year.apply(lambda x:int(x))

# %%
game.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year              int64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %% [markdown]
# ### Describe () method to view some statistical details

# %%
game.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16291.000000  16291.000000  16291.000000  16291.000000  16291.000000
# mean    8290.190228   2006.405561      0.265647      0.147731      0.078833
# std     4792.654450      5.832412      0.822432      0.509303      0.311879
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4132.500000   2003.000000      0.000000      0.000000      0.000000
# 50%     8292.000000   2007.000000      0.080000      0.020000      0.000000
# 75%    12439.500000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16291.000000  16291.000000
# mean       0.048426      0.540910
# std        0.190083      1.567345
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.480000
# ...

# %% [markdown]
# ### checking the object dtype stats

# %%
game.describe(include='object')
# Out:
#                                Name Platform   Genre        Publisher
# count                         16291    16291   16291            16291
# unique                        11325       31      12              576
# top     Need for Speed: Most Wanted       DS  Action  Electronic Arts
# freq                             12     2131    3251             1339

# %%
game.shape
# Out:
# (16291, 11)

# %% [markdown]
# ### 1. Which Publisher has the higest number of Global_Sales

# %%
maxx = game['Global_Sales'].max()
game[game['Global_Sales']==maxx]#[['Name','Publisher']]
# Out:
#    Rank        Name Platform  Year   Genre Publisher  NA_Sales  EU_Sales  \
# 0     1  Wii Sports      Wii  2006  Sports  Nintendo     41.49     29.02
#
#    JP_Sales  Other_Sales  Global_Sales
# 0      3.77         8.46         82.74

# %% [markdown]
# - Wii Sports is a 2006 sports simulation video game developed and published by Nintendo for the Wii video game console.
# - The game was released in North America along with the Wii on November 19, 2006, and was released in Japan, Australia, and Europe the following month
# - As innovation on the Wii is centered around the use of the Wii Remote and not around the graphics pipeline.
# - Wii Sports today might not be as enthusiastic as compared to various different 3d games or high tech games but Wii sports deines the childhood and has  gigantic impact on the world like this game has on based on sports like football, Tennis, Basketball , Baseball Type games
# - Nintendo has the higest Global Sale , Game name Wii Sports around 82 millions

# %% [markdown]
# ### 2. Which is Higest  Publisher

# %%
game.Publisher.value_counts().head(5)
# Out:
# Electronic Arts                 1339
# Activision                       966
# Namco Bandai Games               928
# Ubisoft                          918
# Konami Digital Entertainment     823
# Name: Publisher, dtype: int64

# %%
game.Publisher.sort_values().value_counts()[0]
# Out:
# 1339

# %% [markdown]
# - Electronic Arts Famously known as EA sports  is the largest gaming company in the Americas and Europe by revenue and market capitalization after Activision Blizzard and ahead of Take-Two Interactive, and Ubisoft as of May 2020
# - EA also has another Sports Network EA Sports before being renamed due to a trademark dispute with ESPN.
# - EA Sports publishes all the sports games from EA, including FIFA Football, Madden NFL, Fight Night, NBA Live, NCAA Football, Cricket, etc .
# - In 2011, Forbes ranked EA Sports eighth on their list of most valuable sports brands, with a value of $625 million.
# -  and has most number of games
# - EA has 1339 different games count
# - Activision has 966 games count

# %% [markdown]
# ### 3. In which year the higest Number of games were developed

# %%
game.Year.value_counts()
# Out:
# 2009    1431
# 2008    1428
# 2010    1257
# 2007    1201
# 2011    1136
# 2006    1008
# 2005     936
# 2002     829
# 2003     775
# 2004     744
# 2012     655
# 2015     614
# 2014     580
# 2013     546
# 2001     482
# 1998     379
# 2000     349
# 2016     342
# 1999     338
# 1997     289
# 1996     263
# 1995     219
# 1994     121
# 1993      60
# 1981      46
# 1992      43
# 1991      41
# 1982      36
# 1986      21
# 1989      17
# 1983      17
# 1990      16
# 1987      16
# 1988      15
# 1985      14
# 1984      14
# 1980       9
# 2017       3
# 2020       1
# Name: Year, dtype: int64

# %%
plt.figure(figsize=(11,11))
sns.countplot(data=game, y='Year')
plt.xticks(rotation=30)
plt.title('Higest number of games developed in a year',
         fontdict={'fontname':'Arial Narrow','fontsize':18,'color':'black'})
plt.xlabel('Counts')
plt.ylabel('Years')
sns.set_style('whitegrid')
plt.show()

# %% [markdown]
# - In the Year 2009 the gaming esports was in boom and the gaming style of the developers were begin to change for 2d to 3d, from Nintendo to Andriod , from DS to PS and various different types of genres were developed as well.
# - The year 2009 for gaming was hell of a competitive for various aspects like esports , for publishers, Platforms, Sales, etc
# - In this Year the game which is still today the one of the most played games for the particular consoles like pc , ps , xbox.  - The games like Assassin's Creed ( Renaissance Italy )(Xbox 360, PlayStation 3) ,  Left 4 Dead 2 (Xbox 360, PC) Is the Game of the Year ,   New Super Mario Bros (Wii)  ,    Batman: Arkham (Xbox 360, PlayStation 3, PC)  , Uncharted 2 (PlayStation 3) etc .
# - The Year  2009 were highest number of games developed

# %% [markdown]
# ### 4. Top 10 Most Common Game Publishers in the Year 2009

# %%
game[game['Year']==2009][['Publisher']].value_counts().head(10)
# Out:
# Publisher
# Activision                      121
# Electronic Arts                 112
# Ubisoft                         102
# THQ                              72
# Namco Bandai Games               62
# Konami Digital Entertainment     59
# Sony Computer Entertainment      45
# Sega                             43
# Take-Two Interactive             41
# Nintendo                         32
# dtype: int64

# %%
plt.figure(figsize=(11,6))

x = game[game['Year']==2009]['Publisher'].sort_values().value_counts().head(10)
sns.set_style('darkgrid')
ax = sns.barplot(x.values, x.index)
plt.title("Most Common 'Games Publishers' in the year 2009")
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# - In 2009 Activision (Today famously known as Activision Blizzard) published the most suprising game COD (Call of Duty) and today there are more than 15 Cod games and which are in the Esports and thats why millions of people compete in this game and also  this game is an heart of activision  including the Destiny , Prototype , Blur, Marvel Avengers because of COD games the Activision Top the chart  while nintendo slipped to the bottom along with sega , sony .
#
# - In 2009 ACtivision Published 212 Different games
# - EA published 112 games over the year

# %% [markdown]
# ### 5. Top 20 Games With Most Global Sales

# %%
game.groupby('Name').Global_Sales.sum().sort_values(ascending=False).head(20)
# Out:
# Name
# Wii Sports                        82.74
# Grand Theft Auto V                55.92
# Super Mario Bros.                 45.31
# Tetris                            35.84
# Mario Kart Wii                    35.82
# Wii Sports Resort                 33.00
# Pokemon Red/Pokemon Blue          31.37
# Call of Duty: Modern Warfare 3    30.83
# New Super Mario Bros.             30.01
# Call of Duty: Black Ops II        29.72
# Call of Duty: Black Ops           29.40
# Wii Play                          29.02
# New Super Mario Bros. Wii         28.62
# Duck Hunt                         28.31
# Call of Duty: Ghosts              27.38
# Super Mario World                 26.07
# Call of Duty: Black Ops 3         25.32
# Call of Duty: Modern Warfare 2    25.09
# Nintendogs                        24.76
# Grand Theft Auto: San Andreas     23.86
# Name: Global_Sales, dtype: float64

# %%
x= game.groupby("Name").Global_Sales.sum().sort_values(ascending= False).head(20)

plt.figure(figsize= (11,11))

sns.set_style("whitegrid")

ax= sns.barplot(x.values,x.index)

ax.set_xlabel("global sales(in million)")

plt.title('Top 20 Games With Most Sales',
         fontdict={'fontname':'Comic Sans MS','fontsize':18})
plt.show()

# %% [markdown]
# - Wii sports is an Sports Simulation Video Game Which is Developed and Published By Nintedo Gaming
# - Tops the table with most global sales followed by other popualar games like GTA V (Rockstar Games)and Tetris(EA) super mario we all know mario games, also majority of call of duty games have made it to the top 20 list by sales
# - Wii Sports has the most sales of 82 Million games sold
# - GTA with 55 Million games sold

# %% [markdown]
# ### 6. List the Year 1980 with its Name, Genre, publisher

# %%
game[game['Year']==1980][['Year','Name','Genre','Publisher']]
# Out:
#       Year             Name     Genre   Publisher
# 258   1980        Asteroids   Shooter       Atari
# 544   1980  Missile Command   Shooter       Atari
# 1766  1980          Kaboom!      Misc  Activision
# 1969  1980         Defender      Misc       Atari
# 2669  1980           Boxing  Fighting  Activision
# 4025  1980       Ice Hockey    Sports  Activision
# 5366  1980          Freeway    Action  Activision
# 6317  1980           Bridge      Misc  Activision
# 6896  1980         Checkers      Misc       Atari

# %% [markdown]
# - In the Year 1980's The publishers Atari and Activision were at the top and Misc genre were famous
# - The famous 80 games which are still were in 2d's are still evolved and upgraded with the advanced graphics and 3d animations
# - The 80s games which are still today much famous are: Freeway, Checkers (The Board of chess) , Pac-Man , Pinball, Olympic Decatlon

# %% [markdown]
# ### 7.In  year 2015 which genre has the highest value

# %%
game[game['Year']==2015]['Genre'].value_counts()
# Out:
# Action          255
# Role-Playing     78
# Sports           62
# Adventure        54
# Misc             39
# Shooter          34
# Fighting         21
# Racing           19
# Strategy         17
# Simulation       15
# Platform         14
# Puzzle            6
# Name: Genre, dtype: int64

# %% [markdown]
# - In year 2015 Action Genre Tops the count with the Action games like
# - Bloodborne , Batman Arkham , Fallout 4, Call of Duty as COD games etc Where too much famous because of there stories and      actions
# - In 2005 Action has the highest Genre count of 250 units of action game were sold

# %%
y = game[game['Year']==2015]['Genre'].sort_values().value_counts().head(10)

plt.figure(figsize=(9,4))

sns.set_style('dark')

ax = sns.barplot(y.values, y.index)

plt.title('Year 2015 Higest Genre Value Count',
         fontdict={'fontname':'Comic Sans MS','fontsize':18})
plt.ylabel('Genre')
plt.xlabel('Counts')

plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# ### 8. Top 10  Publisher with the Higest Vaue Count

# %%
game.Publisher.value_counts().head(10)
# Out:
# Electronic Arts                 1339
# Activision                       966
# Namco Bandai Games               928
# Ubisoft                          918
# Konami Digital Entertainment     823
# THQ                              712
# Nintendo                         696
# Sony Computer Entertainment      682
# Sega                             632
# Take-Two Interactive             412
# Name: Publisher, dtype: int64

# %%
plt.figure(figsize=(9,5))

game.Publisher.value_counts().head(10).plot(kind='bar',color='c')

plt.yticks(rotation=30)

plt.title('Top 10 Publishers',
         fontdict={'fontname':'Comic Sans MS','fontsize':15,'color':'black'})

plt.xlabel('Publishers')
plt.ylabel('Counts')

plt.show()

# %% [markdown]
# - Electronic Arts has the higest value count with most games published as the EA sports is famous for the Sports genre and the top game of EA like FIFA as well as NFS (NEED FOR SPEED) and below EA there is Ubisoft, THQ, Sega
# - EA Best Selling titles : BattleField , The Sims, NFS, Star Wars,FIFA, NFL etc.
# - Hence, the EA net worth for this current fiscal year is estimated to be $22.9 billion
# - EA has the 1399 units of different games sold
# - Below EA Activision has 955 units of games sold

# %% [markdown]
# ### 9. What are the Global Sales in Every Year

# %%
game.groupby('Year').Global_Sales.sum()
# Out:
# Year
# 1980     11.38
# 1981     35.77
# 1982     28.86
# 1983     16.79
# 1984     50.36
# 1985     53.94
# 1986     37.07
# 1987     21.74
# 1988     47.22
# 1989     73.45
# 1990     49.39
# 1991     32.23
# 1992     76.16
# 1993     45.98
# 1994     79.17
# 1995     88.11
# 1996    199.15
# 1997    200.98
# 1998    256.47
# 1999    251.27
# 2000    201.56
# 2001    331.47
# 2002    395.52
# 2003    357.85
# 2004    414.01
# 2005    458.51
# 2006    521.04
# 2007    609.92
# 2008    678.90
# 2009    667.30
# 2010    600.29
# 2011    515.80
# 2012    363.49
# 2013    368.11
# 2014    337.03
# 2015    264.44
# 2016     70.90
# 2017      0.05
# 2020      0.29
# Name: Global_Sales, dtype: float64

# %%
x = game.groupby('Year').Global_Sales.sum()

# %%
plt.figure(figsize=(15,5))

sns.lineplot(x.index, x.values ,label='Sales', color='b',ls='--',lw=2, marker='o',markerfacecolor='salmon')

plt.xlabel('Years')
plt.ylabel('Sales in (Millions)')

plt.title('Global Sales per Year',
         fontdict={'fontname':'Comic Sans MS','fontsize':18,'color':'black'})

sns.set_style('whitegrid')

plt.grid(True)

plt.legend()
plt.show()

# %% [markdown]
# - Global sales increase between mid 2000s and reach a peak in 2008 and 2009
# - According to data the amount of video game sold in 2008 reached $- 700 Million
# - A Video game Campany makes More than the global movie and North American sports industries combined. ...

# %% [markdown]
# ### 10. What are the types of Video Game Genres

# %%
game.Genre.unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
game.Genre.value_counts()
# Out:
# Action          3251
# Sports          2304
# Misc            1686
# Role-Playing    1470
# Shooter         1282
# Adventure       1274
# Racing          1225
# Platform         875
# Simulation       848
# Fighting         836
# Strategy         670
# Puzzle           570
# Name: Genre, dtype: int64

# %%
x = game['Genre'].value_counts()

# %%
plt.figure(figsize=(11,11))

label=  ['Action','Sports','Misc','Role-Playing','Shooter','Adventure','Racing','Platform','Simulation','Fighting','Strategy','Puzzle']
color=['c','r','b','pink','black','orange','green','purple','red','grey','yellow','pink']


plt.pie(x, labels=label,colors=color,
       autopct='%.1f  %%',
       shadow=True,
       explode=(0,0.1,0,0,0.1,0,0,0.2,0,0,0,0),
       wedgeprops={'edgecolor':'pink'},
       startangle=30)


plt.legend()
plt.show()

# %% [markdown]
# -  Action followed by sports and shooter games do the best business in video game market
# -  Games like GTA, Fortnite , CSGO , Mario , God of War , Dota , League of Legends , Minecraft , COD gamers are the top games in the history of gaming and eports  and they lies in the Category of Action, Misc, Sports, Shooter

# %%
#Games per genre
plt.figure(figsize= (15,6))


sns.countplot(x= "Genre",data= game)

plt.xticks(rotation=20)
plt.yticks(rotation=20)

plt.title('Games per Genre',
    fontdict={'fontname':'Comic Sans MS','fontsize':23,'color':'black'})

plt.xlabel('Genre')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# ### 11. What are the top Gaming platorm with most sales

# %%
game.groupby('Platform').Global_Sales.sum().sort_values(ascending=False)
# Out:
# Platform
# PS2     1233.46
# X360     969.60
# PS3      949.35
# Wii      909.81
# DS       818.91
# PS       727.39
# GBA      305.62
# PSP      291.71
# PS4      278.10
# PC       254.70
# GB       254.42
# XB       252.09
# NES      251.07
# 3DS      246.27
# N64      218.21
# SNES     200.05
# GC       197.14
# XOne     141.06
# 2600      86.57
# WiiU      81.86
# PSV       61.60
# SAT       33.59
# GEN       28.36
# DC        15.97
# SCD        1.87
# NG         1.44
# WS         1.42
# TG16       0.16
# 3DO        0.10
# GG         0.04
# PCFX       0.03
# Name: Global_Sales, dtype: float64

# %%
plt.figure(figsize=(16,8))

sns.countplot(x='Platform', data=game)

plt.title('Gaming Platform With Most sales',
    fontdict={'fontname':'Comic Sans MS','fontsize':18,'color':'black'})

plt.xticks(rotation=30)
plt.xlabel('Platform')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# - Sony's PlayStation 2 is the best-selling game console overall with over 2000 games worldwide.
# - PlayStation the firm of Sony entertainment  has the highest sale along DS and its strange pc gaming is not even in top 5
# - Nintendo DS family Released 2004 and its games are sold more than 2000
# - PlayStation 2 Released in 2000 and its games are sold  more than Nintendo DS
# - Wii Released 2006 and its games are sold in 1000 units

# %% [markdown]
# ### 12. What are gaming Platform with most games

# %%
game.Platform.value_counts()
# Out:
# DS      2131
# PS2     2127
# PS3     1304
# Wii     1290
# X360    1234
# PSP     1197
# PS      1189
# PC       938
# XB       803
# GBA      786
# GC       542
# 3DS      499
# PSV      410
# PS4      336
# N64      316
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     116
# NES       98
# GB        97
# DC        52
# GEN       27
# NG        12
# WS         6
# SCD        6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: Platform, dtype: int64

# %%
x1 = game.Platform.value_counts()

# %%
plt.figure(figsize=(15,5))

plt.plot(x1.index, x1.values ,label='Games', color='c',ls='--',lw=2, marker='o',markerfacecolor='salmon')


plt.xlabel('Console')
plt.ylabel('Most Games(in units)')

plt.title('Gaming Platorm With Most games',
         fontdict={'fontname':'Comic Sans MS','fontsize':18,'color':'black'})

sns.set_style('whitegrid')


plt.grid(True)

plt.legend()
plt.show()

# %% [markdown]
# - PlayStation might top the Higest Sales but the PLatoform DS is the firm of Nintendo Gaming and Therefore every one knew
# - That nintendo is the gaming culture of 90s it will surely has most games then rest of the Platform

# %% [markdown]
# ### 13. North American vs European game sales

# %%
plt.figure(figsize=(15,5))
sns.scatterplot(x='NA_Sales', y='EU_Sales', data=game, hue='Genre')
plt.title('NA vs EU Game Sales',
         fontdict={'Fontname':'Comic Sans MS', 'fontsize':18,'color':'black'})

plt.plot()
# Out:
# []

# %%
a = game.groupby('Year').NA_Sales.sum()

# %%
b = game.groupby('Year').EU_Sales.sum()

# %%
plt.figure(figsize=(12,4))

sns.lineplot(a.index, a.values, label='NA', ls='--',lw=2,marker='>',markerfacecolor='salmon')
sns.lineplot(b.index, b.values, label='EU',ls='--',lw=2,marker='o',markerfacecolor='salmon')

plt.xlabel('Years')
plt.ylabel('Sales')


plt.title('NA vs EU Game Sales',
         fontdict={'Fontname':'Comic Sans MS', 'fontsize':18,'color':'black'})

plt.show()

# %% [markdown]
# - In 2008  as compared to EU, NA has the higest number of games sales (350 millions)
# - In 2009 EU has the higest sale of its region (200 million)
# - In 2013 EU and NA has equals sales around (150 million)
# - By this graph definatly NA has most sales then EU

# %% [markdown]
# ### 14. Japan vs America Sales

# %%
plt.figure(figsize=(15,5))
sns.scatterplot(x='JP_Sales', y='NA_Sales', data=game, hue='Genre')
plt.title('JP vs NA Game Sales',
         fontdict={'Fontname':'Comic Sans MS', 'fontsize':18,'color':'black'})

plt.plot()
# Out:
# []

# %%
a1 = game.groupby('Year').JP_Sales.sum()

# %%
b1 = game.groupby('Year').NA_Sales.sum()

# %%
plt.figure(figsize=(12,4))

sns.lineplot(a1.index, a1.values, label='JP', ls=':',lw=2,marker='p',markerfacecolor='blue',color='red',markeredgewidth=1)
sns.lineplot(b1.index, b1.values, label='NA',ls=':',lw=2,marker='o',markerfacecolor='salmon')

plt.xlabel('Years')
plt.ylabel('Sales')


plt.title('JP vs NA Game Sales',
         fontdict={'Fontname':'Comic Sans MS', 'fontsize':18,'color':'black'})

plt.show()

# %% [markdown]
# - Japan Higest peek for sales was in the year 2006-2007 around(75 million)
# - In the year 1995-1996 japan and NA both has same sales around(50 million)
# - As compared to japan , NA has most sales , more than a 200 million

# %% [markdown]
# ### 15 Europe vs Japan Sales

# %%
plt.figure(figsize=(15,5))

sns.scatterplot(x='EU_Sales', y='JP_Sales', data=game, hue='Genre')

plt.title('EU vs JP Game Sales',
         fontdict={'Fontname':'Comic Sans MS', 'fontsize':18,'color':'black'})


plt.plot()
# Out:
# []

# %%
j = game.groupby('Year').JP_Sales.sum()

# %%
e = game.groupby('Year').EU_Sales.sum()

# %%
plt.figure(figsize=(12,4))

sns.lineplot(j.index, j.values, label='JP', ls='-.',lw=2,marker='p',markerfacecolor='salmon',color='black',markeredgewidth=1)
sns.lineplot(e.index, e.values, label='NA',ls='-.',lw=2,marker='o',markerfacecolor='salmon',color='green')

plt.xlabel('Years')
plt.ylabel('Sales')

sns.set_style('whitegrid')

plt.title('JP vs EU Game Sales',
         fontdict={'Fontname':'Comic Sans MS', 'fontsize':18,'color':'black'})

plt.show()

# %% [markdown]
# - EU higest sales was in the Year 2008 and it was 190 million
# - As compared to japan sales EU sales are much higher
# - In Year 200 they both have same sales (50 million)

# %% [markdown]
# ### 16. All Regions Sales Comparison

# %%
plt.figure(figsize=(12,4))

n = game.groupby('Year').NA_Sales.sum()
e = game.groupby('Year').EU_Sales.sum()
j = game.groupby('Year').JP_Sales.sum()


sns.lineplot(n.index, n.values, label='NA')
sns.lineplot(e.index, e.values, label='EU')
sns.lineplot(j.index, j.values, label='JP')


plt.title('JP vs EU Game Sales',
         fontdict={'Fontname':'Comic Sans MS', 'fontsize':18,'color':'black'})

plt.show()

# %% [markdown]
# - As cleared, NA has the highest sale in the year over all years
# - Europe comes 2nd in sales and then the Japan region

# %% [markdown]
# ### 17 What are the  Top Games in NA Region

# %%
game.groupby('Name').NA_Sales.sum().sort_values(ascending=False).head(10)
# Out:
# Name
# Wii Sports                        41.49
# Super Mario Bros.                 32.48
# Duck Hunt                         26.93
# Tetris                            26.17
# Grand Theft Auto V                23.46
# Call of Duty: Black Ops           17.01
# Super Mario World                 15.99
# Mario Kart Wii                    15.85
# Wii Sports Resort                 15.75
# Call of Duty: Modern Warfare 3    15.58
# Name: NA_Sales, dtype: float64

# %% [markdown]
# - NA region most famous game is WIi sports with 41% as compared to Super Mario Bros with 32%
# - Looks like NA region loves GTA games as well as Call of duty games

# %% [markdown]
# ### 18. What are the Top Platform With Most Sales in North America Region

# %%
game.groupby("Platform").NA_Sales.sum().sort_values(ascending= False).head(10)
# Out:
# Platform
# X360    594.33
# PS2     572.92
# Wii     497.37
# PS3     388.90
# DS      388.53
# PS      334.71
# XB      182.06
# GBA     178.43
# N64     138.91
# GC      131.94
# Name: NA_Sales, dtype: float64

# %%
x= game.groupby("Platform").NA_Sales.sum().sort_values(ascending= False).head(10)

sns.barplot(x.values, x.index)

plt.xlabel('Values')
plt.ylabel('Platform')

plt.title('Most sales in NA Region',
         fontdict={'Fontname':'Comic Sans MS', 'fontsize':12,'color':'black'})

plt.plot()
# Out:
# []

# %% [markdown]
# - In NA region there are 595 units of Xbox 360 games
# - 573 total number of PS2 games
# - Wii has 498 total number of games
# - at the bottom GC has only 120 Games in NA region

# %% [markdown]
# ### 19. What are the top 10 games in Japan

# %%
game.groupby('Name').JP_Sales.sum().sort_values(ascending=False).head(10)
# Out:
# Name
# Pokemon Red/Pokemon Blue              10.22
# Pokemon Gold/Pokemon Silver            7.20
# Super Mario Bros.                      6.96
# New Super Mario Bros.                  6.50
# Pokemon Diamond/Pokemon Pearl          6.04
# Tetris                                 6.03
# Pokemon Black/Pokemon White            5.65
# Dragon Quest VII: Warriors of Eden     5.40
# Pokemon Ruby/Pokemon Sapphire          5.38
# Animal Crossing: Wild World            5.33
# Name: JP_Sales, dtype: float64

# %%
x = game.groupby('Name').JP_Sales.sum().sort_values(ascending=False).head(10)

# %%
plt.figure(figsize=(14,5))
sns.barplot(x.index, x.values, color='c')

sns.set_style('whitegrid')

plt.xticks(rotation=90)

plt.title('Japan top 10 games',
         fontdict={'Fontname':'Comic Sans MS', 'fontsize':14,'color':'black'})

plt.xlabel('Names')
plt.ylabel('Counts')
plt.plot()
# Out:
# []

# %% [markdown]
#                           - The anime country loves Pokemon games above mario

# %% [markdown]
# ### 20. What are the top 10 Publishers in Japan

# %%
game.groupby('Publisher').JP_Sales.sum().sort_values(ascending=False).head(10)
# Out:
# Publisher
# Nintendo                        454.99
# Namco Bandai Games              126.84
# Konami Digital Entertainment     90.93
# Sony Computer Entertainment      74.10
# Capcom                           67.38
# Sega                             56.19
# Square Enix                      49.79
# SquareSoft                       40.13
# Enix Corporation                 32.40
# Tecmo Koei                       29.21
# Name: JP_Sales, dtype: float64

# %%
y = game.groupby('Publisher').JP_Sales.sum().sort_values(ascending=False).head(10)

# %%
plt.figure(figsize=(14,3))

plt.fill_between(y.index,y.values,interpolate=True,alpha=0.65)
sns.lineplot(y.index, y.values,ls=':',lw=2,marker='o')

plt.xticks(rotation=90)

plt.xlabel('Publisher')
plt.ylabel('Count(in millions)')

plt.title('Japan top 10 Publisher',
         fontdict={'Fontname':'Comic Sans MS', 'fontsize':14,'color':'black'})


sns.set_style('white')

plt.plot()
# Out:
# []

# %% [markdown]
# - In Japan not many Quantity of games are sold as compare to EU and NA but Nintendo is the top most selling Publisher in Japan with sales over 454 millions

# %% [markdown]
# ### 21. What are the top 10 Platform in Japan

# %%
game.groupby('Platform').JP_Sales.sum().sort_values(ascending=False).head(10)
# Out:
# Platform
# DS      175.02
# PS      139.78
# PS2     137.54
# SNES    116.55
# NES      98.65
# 3DS      97.30
# GB       85.12
# PS3      79.21
# PSP      75.89
# Wii      68.28
# Name: JP_Sales, dtype: float64

# %%
z = game.groupby('Platform').JP_Sales.sum().sort_values(ascending=False).head(10)

# %%
plt.figure(figsize=(14,5))

plt.fill_between(z.values,z.index,interpolate=True,alpha=0.15)
sns.lineplot(z.values, z.index,ls='-.',lw=1,marker='o',markerfacecolor='c')


plt.xlabel('Platform')
plt.ylabel('Count')

plt.title('Japan top 10 Platform',
         fontdict={'Fontname':'Comic Sans MS', 'fontsize':14,'color':'black'})

sns.set_style('white')


plt.plot()
# Out:
# []

# %% [markdown]
# ### 22. What are the top 10 Games in Europe

# %%
game.groupby('Name').EU_Sales.sum().sort_values(ascending=False).head(10)
# Out:
# Name
# Wii Sports                        29.02
# Grand Theft Auto V                23.04
# Mario Kart Wii                    12.88
# FIFA 15                           12.40
# Call of Duty: Modern Warfare 3    11.29
# FIFA 16                           11.29
# FIFA 14                           11.14
# Call of Duty: Black Ops II        11.05
# Wii Sports Resort                 11.01
# Nintendogs                        11.00
# Name: EU_Sales, dtype: float64

# %% [markdown]
#  - Every Region loves the Wii sports games and COD games with same as EU

# %% [markdown]
# ### 23. How many of the mario games were Globally sale

# %%
game.Name.str.contains("Mario").value_counts()
# Out:
# False    16179
# True       112
# Name: Name, dtype: int64

# %% [markdown]
# - There are total of 112 Mario  Games in the Data which are Globally sold

# %% [markdown]
# ### 24. How many games were made in the year 2010

# %%
game[game['Year']==2010]['Name'].count()
# Out:
# 1257

# %% [markdown]
# - In 2010 1257 Total number of games were made as compared to the year 2009 the number of games were more then 2000

# %% [markdown]
# ### 25. How many Sports games are made

# %%
len(game[game['Genre']=='Sports'])
# Out:
# 2304

# %% [markdown]
# - There are  2304 of total sports Genre in the data

# %% [markdown]
# ### 26. Top 5 FIFA games

# %%
game[game['Name'].str.startswith('FIFA')].head()
# Out:
#      Rank            Name Platform  Year   Genre        Publisher  NA_Sales  \
# 77     78         FIFA 16      PS4  2015  Sports  Electronic Arts      1.11
# 82     83  FIFA Soccer 13      PS3  2012  Action  Electronic Arts      1.06
# 112   113         FIFA 14      PS3  2013  Sports  Electronic Arts      0.78
# 121   122         FIFA 12      PS3  2011  Sports  Electronic Arts      0.84
# 124   125         FIFA 15      PS4  2014  Sports  Electronic Arts      0.79
#
#      EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 77       6.06      0.06         1.26          8.49
# 82       5.05      0.13         2.01          8.24
# 112      4.32      0.07         1.73          6.90
# 121      4.32      0.11         1.42          6.69
# 124      4.29      0.05         1.47          6.59

# %% [markdown]
# - fifa 16 was developed in the year 2016 has the most Global Sales around 8 ml
# - As compared to rest of the fifa games the fifa 15 which was developed in the year 2015 has not much impact because of the fifa 15 gameply and graphics

# %%
bsns.pairplot(game)
plt.plot()
# Out:
# []

# %% [markdown]
# ### Conclusion

# %% [markdown]
# - North America Tops the region in every ascpect, Global Sales , Other Sales etc
# - Wii Sports is the most sold game in North America and European Union.
# - Pokemon Red/Pokemon Blue is the most sold same in Japan.
# - GTA San Andreas is the most sold game in other regions.
# - Wii Sports is the most sold game globally.
# - Action Genre does the best business in video games
# - The top gaming Companies make around  200 - 300 million.
# - Wii Games is the most played games in NA, EU
# - Nintendo Publishers has got the most sales in every regions
# - The Year 2009 was the best year and most successful year with most number of games sold and the most number of sales achieved
